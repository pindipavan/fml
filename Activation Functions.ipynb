# %% [markdown]
# Sigmoid Function

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

x=np.linspace(-10,10)
plt.plot(x,sigmoid(x))
plt.axis('tight')
plt.title('sigmoid function')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Tanh function** using math functions

# %%
def tanh(x):
  return np.tanh(x)

x=np.linspace(-10,10)
y=np.linspace(-1,1)
plt.plot(x,tanh(x))
plt.axis('tight')
plt.title('Tanh function')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Tanhy function using formula

# %%
def sigmoid(x):
  return np.exp(x)-np.exp(-x)/np.exp(x)+np.exp(-x)

x=np.linspace(-10,10)
plt.plot(x,tanh(x))
plt.axis('tight')
plt.title('Tanh function')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ReLU function

# %%
def RELU(x):
  x1=[]
  for i in x:
    if i<0:
      x1.append(0)
    else:
      x1.append(i)

  return x1

x=np.linspace(-10,10)
plt.plot(x,RELU(x))
plt.axis('tight')
plt.title('RELU function')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
